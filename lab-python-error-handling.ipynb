# %% [markdown]
# # Lab | Error Handling

# %% [markdown]
# ## Exercise: Error Handling for Managing Customer Orders
#
# The implementation of your code for managing customer orders assumes that the user will always enter a valid input.
#
# For example, we could modify the `initialize_inventory` function to include error handling.
#    - If the user enters an invalid quantity (e.g., a negative value or a non-numeric value), display an error message and ask them to re-enter the quantity for that product.
#    - Use a try-except block to handle the error and continue prompting the user until a valid quantity is entered.
#
# ```python
# # Step 1: Define the function for initializing the inventory with error handling
# def initialize_inventory(products):
#     inventory = {}
#     for product in products:
#         valid_quantity = False
#         while not valid_quantity:
#             try:
#                 quantity = int(input(f"Enter the quantity of {product}s available: "))
#                 if quantity < 0:
#                     raise ValueError("Invalid quantity! Please enter a non-negative value.")
#                 valid_quantity = True
#             except ValueError as error:
#                 print(f"Error: {error}")
#         inventory[product] = quantity
#     return inventory
#
# # Or, in another way:
#
# def initialize_inventory(products):
#     inventory = {}
#     for product in products:
#         valid_input = False
#         while not valid_input:
#             try:
#                 quantity = int(input(f"Enter the quantity of {product}s available: "))
#                 if quantity >= 0:
#                     inventory[product] = quantity
#                     valid_input = True
#                 else:
#                     print("Quantity cannot be negative. Please enter a valid quantity.")
#             except ValueError:
#                 print("Invalid input. Please enter a valid quantity.")
#     return inventory
# ```
#
# Let's enhance your code by implementing error handling to handle invalid inputs.
#
# Follow the steps below to complete the exercise:
#
# 2. Modify the `calculate_total_price` function to include error handling.
#    - If the user enters an invalid price (e.g., a negative value or a non-numeric value), display an error message and ask them to re-enter the price for that product.
#    - Use a try-except block to handle the error and continue prompting the user until a valid price is entered.
#
# 3. Modify the `get_customer_orders` function to include error handling.
#    - If the user enters an invalid number of orders (e.g., a negative value or a non-numeric value), display an error message and ask them to re-enter the number of orders.
#    - If the user enters an invalid product name (e.g., a product name that is not in the inventory), or that doesn't have stock available, display an error message and ask them to re-enter the product name. *Hint: you will need to pass inventory as a parameter*
#    - Use a try-except block to handle the error and continue prompting the user until a valid product name is entered.
#
# 4. Test your code by running the program and deliberately entering invalid quantities and product names. Make sure the error handling mechanism works as expected.

# %%
def initialize_inventory(products):
    """
    The function initialize_inventory takes products as a parameter and initializes the inventory dictionary using a dictionary comprehension.
    """
    inventory = {}
    for product in products:
        valid_quantity = False
        while not valid_quantity:
            try:
                quantity = int(input(f"Enter the quantity of {product}s available: "))
                if quantity < 0:
                    raise ValueError("Invalid quantity! Please enter a non-negative value.")
                valid_quantity = True
            except ValueError as error:
                print(f"Error: {error}")
        inventory[product] = quantity
    return inventory

def get_customer_orders(products, inventory):
    """
    The function get_customer_orders prompts the user to enter the number of customer orders 
    and gathers the product names using a loop and user input. It uses comprehension.
    """
    customer_orders = {}
    while True:
        valid_order = False
        while not valid_order:
            try:
                num_orders = int(input("Enter the number of orders: "))
                if num_orders < 0:
                    raise ValueError("Invalid number of orders! Please enter a non-negative value.")
                valid_order = True
            except ValueError as error:
                print(f"Error: {error}")
                
        for _ in range(num_orders):
            valid_product = False
            while not valid_product:
                product_name = input("Enter the name of a product that a customer wants to order (t-shirt, mug, hat, book, keychain): ")
                if product_name in products and inventory.get(product_name, 0) > 0:
                    valid_product = True
                else:
                    print("Invalid product name or out of stock. Please enter a valid product name (t-shirt, mug, hat, book, keychain).")
            customer_orders[product_name] = customer_orders.get(product_name, 0) + 1
            
        add_another = input("Do you want to add another product? (yes/no): ")
        if add_another.lower() != 'yes':
            break
    return customer_orders

def calculate_total_price(customer_orders):
    """
    The function calculate_total_price calculates the total price of the customer order. It prompts the user to enter the price of each product and uses comprehension to calculate the total price.
    """
    total_price = 0
    for product, quantity in customer_orders.items():
        valid_price = False
        while not valid_price:
            try:
                price = float(input(f"Enter the price of {product}: "))
                if price < 0:
                    raise ValueError("Invalid price! Please enter a non-negative value.")
                valid_price = True
            except ValueError as error:
                print(f"Error: {error}")
        total_price += price * quantity
    return total_price

def update_inventory(customer_orders, inventory):
    """
    The function update_inventory updates the inventory dictionary based on the customer orders. It uses comprehension to filter out products with a quantity of zero.
    """
    for product, quantity in customer_orders.items():
        inventory[product] -= quantity
    inventory = {product: quantity for product, quantity in inventory.items() if quantity > 0}
    return inventory

def calculate_order_statistics(customer_orders, inventory):
    """
    The function calculates the order statistics (total products ordered, and percentage of unique products ordered) and returns these values.
    """
    total_products_ordered = sum(customer_orders.values())
    total_inventory = sum(inventory.values())
    percentage_ordered = total_products_ordered / total_inventory * 100
    order_statistics = (total_products_ordered, percentage_ordered)
    return order_statistics

def print_order_statistics(order_statistics):
    """
    The function prints the order statistics.
    """
    total_products_ordered, percentage_ordered = order_statistics
    print("\nOrder Statistics:")
    print(f"Total Products Ordered: {total_products_ordered}")
    print(f"Percentage of Unique Products Ordered: {percentage_ordered:.1f}%")

def print_updated_inventory(inventory):
    """
    The function prints the updated inventory.
    """
    print("\nUpdated Inventory:")
    for product, quantity in inventory.items():
        print(f"{product}: {quantity}")

# we define a list called products which contains the items
products = ["t-shirt", "mug", "hat", "book", "keychain"]

# calling the functions in the right order
inventory = initialize_inventory(products)
customer_orders = get_customer_orders(products, inventory)
total_price = calculate_total_price(customer_orders)
inventory = update_inventory(customer_orders, inventory)
order_statistics = calculate_order_statistics(customer_orders, inventory)

print_order_statistics(order_statistics)
print_updated_inventory(inventory)
print(f"\nTotal Price: {total_price:.1f}")
# Out:
# Enter the quantity of t-shirts available:  2
# Enter the quantity of mugs available:  3
# Enter the quantity of hats available:  4
# Enter the quantity of books available:  5
# Enter the quantity of keychains available:  6
# Enter the number of orders:  7
# Enter the name of a product that a customer wants to order (t-shirt, mug, hat, book, keychain):  mug
# Enter the name of a product that a customer wants to order (t-shirt, mug, hat, book, keychain):  book
# Enter the name of a product that a customer wants to order (t-shirt, mug, hat, book, keychain):  d
# Invalid product name or out of stock. Please enter a valid product name (t-shirt, mug, hat, book, keychain).
